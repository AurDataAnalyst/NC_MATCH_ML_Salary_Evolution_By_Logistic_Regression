# %%
URL = 'https://www.indeed.fr/jobs?q=data+science&l=Paris&start=0'

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
## YOUR CODE HERE
r = requests.get(URL)

soup = BeautifulSoup(r.text, 'html.parser')

jobs = soup.find_all(name='div', attrs={'class':"result"})

# %%
def extract_company_from_result(html):
    try:
        return html.find("span",{"class":"company"}).text
    except:
        return None

# %%
def extract_salary_from_result(html):
    try:
        html = html.find("span",{"class":"no-wrap"}).text
        return html.replace(u'\xa0', '')
    except:
        return None

# %%
def extract_location_from_result(html):   
    try:
        return html.find("span",{'class':'location'}).text
    except:
        return None

# %%
def extract_job_from_result(html):
    try:
        return html.find("a").text
    except:
        return None

# %%
import unicodedata
url_template = "https://www.indeed.fr/jobs?q=data+science&l={}&start={}"
max_results_per_city = 2000
results = []
#html = html_raw.replace('\xa0','')

for city in ['Paris', 'Courbevoie','Levallois-Perret','Puteaux','Asnières-sur-seine','Nanterre']:
    for start in tqdm(range(0, max_results_per_city, 10)):
        r1 = requests.get(url_template.format(city,start))

        soup = BeautifulSoup(r1.text, 'html.parser')
        #soup.prettify(formatter=lambda s: s.replace(u'\xa0', ' '))
        
        jobs = soup.find_all(name='div', attrs={'class':"result"}) # Grab the results from the request (as above)
        #jobsnew = unicodedata.normalize("NFKD",jobs.text)
        results.extend(jobs) # Append to the full set of results
# Out:
# 100%|██████████| 200/200 [01:34<00:00,  2.12it/s]
# 100%|██████████| 200/200 [01:35<00:00,  2.10it/s]
# 100%|██████████| 200/200 [01:36<00:00,  2.07it/s]
# 100%|██████████| 200/200 [01:34<00:00,  2.13it/s]
# 100%|██████████| 200/200 [01:33<00:00,  2.14it/s]
# 100%|██████████| 200/200 [01:36<00:00,  2.07it/s]

# %%
## YOUR CODE HERE
dflist = [{"job_title":extract_job_from_result(result),"company":extract_company_from_result(result),
      "location":extract_location_from_result(result),"salary":extract_salary_from_result(result)} for result in results]
#dflist.replace('&nbsp;',' ')

#dflist=dflist.replace(" ", "")
#dflist.update({" ":""})

# %%
#df1=df.replace({'\n':''}, regex=True)
#df.replace(to_replace="\n",value="",regex=False,inplace=True)
#df = df.replace("\n", "")
#df1 = [df.replace("\n", "") for df in df1]
#df.replace({'\n': ''})
import pandas as pd
import re
df=pd.DataFrame(dflist)
df = df.replace({'\n':''}, regex=True)
#df = df.replace({' ':''}, regex=True)
#df = df.replace({'&nbsp;':''}, regex=True)
#df['salary'] =re.sub('(?<=\d) (?=\d)', '', df['salary']).astype(str)
#df['salary'] = df['salary'].str.replace(" 0", "0")
#df['salary']=df['salary'].apply(str)
#df['salary'] = df['salary'].str.replace("0 ", "0")
#df.salary.str.replace(',', '').apply(extract_average)
#df['salary'] = df.salary.str.replace(" 0", "0")
#df['salary'] = df.salary.str.replace("&nbsp;","")
#df['salary'] = df['salary'].replace({" 0": "0"}, regex=True)
df.head(50)
# Out:
#                                             job_title  \
# 0                            STAGE DATA SCIENCE (H/F)
# 1                                  Data Scientist H/F
# 2                      Cloud Engineer (AWS) H/F - CDI
# 3                   Clinical Site Manager II / CRA II
# 4                       Senior Data Scientist FinTech
# 5                             Project Data Management
# 6   Junior Data Science / Machine Learning Enginee...
# 7         STAGE - Assistant(e) Data Science, EMEA H/F
# 8   Stage Data Science - Graphes de connaissances ...
# 9                              STAGIAIRE DATA SCIENCE
# 10                     Stagiaire Data Scientist (H/F)
# 11                             STAGIAIRE DATA SCIENCE
# 12  Stage - R&I - Data Science/Machine learning - ...
# 13                     Stage Data Science H/F (Paris)
# 14                          Docteur.e en data science
# 15                                DATA ENGINEER (H/F)
# 16                         MANAGER DATA SCIENCE (H/F)
# 17                                 Data Scientist H/F
# 18                       Principal Data Scientist H/F
# 19             INGENIEUR RECHERCHE DATA SCIENCE (H/F)
# 20        Data Entry Clerk & Administrative assistant
# 21  Data Science / Machine Learning Engineer H/F (...
# 22     Research Data Science Intern - Active Learning
# 23                                     Ingénieur data
# 24              Research Data Science Intern - autoML
# 25               Data Science Consultant Intern (h/f)
# 26  Stage - Data Science dans la production Renouv...
# 27  Consultant Junior en Data Science – Mazars Zet...
# 28     Ingénieur IA - Data Science Optimisation (H/F)
# 29                           PRODUCT OWNER DATA (H/F)
# 30               CONSULTANT SENIOR DATA SCIENCE (H/F)
# 31                           STAGE DATA SCIENCE (H/F)
# 32
# 33                                     Design Manager
# 34                           STAGE DATA SCIENCE (H/F)
# 35                      Un.e Stagiaire Data Scientist
# 36                           CDD - Data Scientist H/F
# 37                       Stagiaire Data Scientist H/F
# 38              Research Data Science Intern - autoML
# 39                       Stage en Data Science and BI
# 40  Data Science / Machine Learning Engineer H/F (...
# 41                  ÉCONOMISTE / DATA SCIENTIST - H/F
# 42  Stage - Data Science dans la production Renouv...
# 43     Research Data Science Intern - Active Learning
# 44                                Mentor Data Science
# 45                            Project Data Management
# 46  Commercial Sédentaire Immobilier - 50K€ (packa...
# 47                                 Data Scientist H/F
# 48                              Architect Sols Arch N
# 49                                DATA ENGINEER (H/F)
#
#                                               company         location  \
# 0                                      Epsilon France             None
# 1                                        Ad Scientiam             None
# 2                                          Jellysmack             None
# 3                                             PAREXEL             None
# 4                                        Easy Partner             None
# 5                                   NES Global Talent             None
# 6                                            Artur'In       Paris (75)
# 7                                             Ubisoft       Paris (75)
# 8                                             BPCE SA       Paris (75)
# 9                                          RELX Group       Paris (75)
# 10                                          Carrefour   Paris 13e (75)
# 11                                      LexisNexis SA       Paris (75)
# 12                                            L'Oreal       Paris (75)
# 13                                             Keyrus       Paris (75)
# 14                                      Science me Up       Paris (75)
# 15                                     Epsilon France             None
# 16                                     Epsilon France             None
# 17                                       Ad Scientiam             None
# 18                                             Safran             None
# 19                                             Airbus       Paris (75)
# 20  European Society for Blood and Marrow transpla...       Paris (75)
# 21                                           Artur'In       Paris (75)
# 22                                            Dataiku       Paris (75)
# 23                                          DATATORII       Paris (75)
# 24                                            Dataiku       Paris (75)
# 25                                    Nova Consulting       Paris (75)
# 26                                                EDF   Palaiseau (91)
# 27                                             Mazars       Paris (75)
# 28                                            ACCENTA       Paris (75)
# 29                                     Epsilon France             None
# 30                                     Epsilon France             None
# 31                                     Epsilon France             None
# 32                                             Kforce             None
# 33                                               ICDS             None
# 34                                     Epsilon France             None
# 35                                         Greenpeace   Paris 10e (75)
# 36                                  La Banque Postale       Paris (75)
# 37                                       Kaisens Data  La Défense (92)
# 38                                            Dataiku       Paris (75)
# 39                                          Innoscape       Paris (75)
# 40                                           Artur'In       Paris (75)
# 41                                La Banque de France       Paris (75)
# 42                                                EDF   Palaiseau (91)
# 43                                            Dataiku       Paris (75)
# 44              OpenClassrooms - Mentorship Team (FR)   Paris 10e (75)
# 45                                  NES Global Talent             None
# 46                                   MEILLEURS AGENTS             None
# 47                                       Ad Scientiam             None
# 48                                            Verizon             None
# 49                                     Epsilon France             None
#
#                       salary
# 0            1300 € par mois
# 1                       None
# 2                       None
# 3                       None
# 4   75000 € - 85000 € par an
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
# 10                      None
# 11                      None
# 12           1250 € par mois
# 13           1200 € par mois
# 14                      None
# 15                      None
# 16                      None
# 17                      None
# 18                      None
# 19                      None
# 20  19000 € - 22000 € par an
# 21                      None
# 22                      None
# 23                      None
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                      None
# 29                      None
# 30                      None
# 31           1300 € par mois
# 32                      None
# 33                      None
# 34           1300 € par mois
# 35           1000 € par mois
# 36                      None
# 37                      None
# 38                      None
# 39                      None
# 40                      None
# 41                      None
# 42                      None
# 43                      None
# 44                      None
# 45                      None
# 46                      None
# 47                      None
# 48                      None
# 49                      None

# %%
#df['salary'] = df['salary'].str.replace(r'\D+', '')
#df.head(50)
df.to_csv("master1_df.csv")

# %%
## YOUR CODE HERE
df1= df.replace({'\n':''}, regex=True)
#df1 = df1[df1['job_title'].str.contains('NaN', na=False)]['Status']
#df1=df1.loc[df.str.contains("NaN", na=False)]
#df1=df1.loc[df.str.contains("NA", na=False)]
df1.job_title.str.contains("NaN", na=False)
df1 = df.loc[~df['salary'].isnull()].drop_duplicates()
df2 = df1.loc[df1.salary.str.contains("an")]
# df2= df1.replace({'par':''}, regex=True)
# df2= df1.replace({'an':''}, regex=True
#df2 = df1.loc[df1.salary.str.contains("mois")]=None
# df3 = df2[~df2["col"]astype(str).str.contains('an')]

# yourValue = 'an'
# for cols in df2.salary:
# 	if (yourValue in df[cols]:
                 
# if 'an' not in df2['salary'].values:   
#     df['salary'] = None
                 
# df2=df1.loc[df1['salary'].str.contains('mois')]=None                
# df2=df1.loc[df1['salary'].str.contains('heure')]=None
# df2=df1.loc[['salary'].str.contains('jour')]=None
#df2['salary']=df2['salary'].replace({" ":""}, regex=True)
df2.head(50)
# Out:
#                                               job_title  \
# 4                         Senior Data Scientist FinTech
# 20          Data Entry Clerk & Administrative assistant
# 50                                   Data scientist H/F
# 54                             DATA SCIENTIST-ENGINEERS
# 83    Data analyste informatique - Plateforme pour l...
# 84                             Data Engineer - Foodtech
# 122                           Data Scientist Junior F/H
# 128   Data Scientist - Plateforme pour les étudiants...
# 138                CHARGE DE CLIENTÈLE A DISTANCE (H/F)
# 159                                   Junior Data Entry
# 168      Senior Data Scientist – Start Up Fintech - H/F
# 173                 [CDI] Data Scientist-Engineer (F&H)
# 211   Gestionnaire middle office crédits particulier...
# 226   Directeur Data Science pour porter l'offre dat...
# 263                                       Data Engineer
# 312       Data Scientist Senior (équipe big data et IA)
# 360                         Lead Technique Data Science
# 364    Big Data Engineer H/F (IoT, Scala, Spark, Kafka)
# 389                        Ingénieur Machine Learning |
# 421   Consultant data science on site pour un jeune ...
# 463                                          Data Miner
# 467                                Data Scientist - NLP
# 529                                           Associate
# 530                                 Lead Data Scientist
# 549                    Développeur(euse) Big Data (H/F)
# 550   Data scientist Phd pour révolutionner le monde...
# 564                       Consultant(e) (jeune diplômé)
# 596   Ingénieur Consultant Recherche et Innovation -...
# 600                   TECHNICIEN SUPPORT APPLICATIF H/F
# 695                     Data Engineer pour une scale up
# 723   Manager Data pour un cabinet de conseil disrup...
# 800   Data scientist/engineer pour un acteur majeur ...
# 850   FullStack Developer for Open Science [VueJs/Ex...
# 852                            Data Engineer - Foodtech
# 891                      Data Scientist - Jeune Docteur
# 944                           Biostaticien /programmeur
# 1095                         VP Sales – Start-up AdTech
# 1097                              Data Manager SNDS H/F
# 1117                   Experimented Data Engineer - H/F
# 1192  Data engineer Python pour une marketplace à fo...
# 1210                     Chargé∙e de campagne marketing
# 1319                    Senior Data Scientist - FinTech
# 1327                           Développeur Frontend H/F
# 1432                                    Data Architecte
# 1508                                Data Engineer - H/F
# 1510         Responsable ou Chargé de Marketing Digital
# 1701       Chargé d’enseignements en Mécatronique (CDI)
# 1743                        Développeur Front-end [CDI]
# 1774   Data Engineer sénior – plateforme de recrutement
# 1797                 Chargé de pharmacovigilance senior
#
#                                                 company         location  \
# 4                                          Easy Partner             None
# 20    European Society for Blood and Marrow transpla...       Paris (75)
# 50                                               Fed IT             None
# 54                                               Axance   Paris 18e (75)
# 83                                         Easy Partner             None
# 84                                         Easy Partner             None
# 122                                      ESSILOR FRANCE     Créteil (94)
# 128                                        Easy Partner             None
# 138                                  Bourse des crédits    Paris 2e (75)
# 159   European Society for bllod and marrow transpla...       Paris (75)
# 168                                        EASY PARTNER             None
# 173                                   Axance Technology   Paris 18e (75)
# 211                                  Bourse des crédits    Paris 2e (75)
# 226                                    Data Recrutement       Paris (75)
# 263                                              Neoxia       Paris (75)
# 312                                               DRYFT       Paris (75)
# 360                                          Harnham US       Paris (75)
# 364                                        Square Sense       Paris (75)
# 389                                          OCTOPUS IT       Paris (75)
# 421                                    Data Recrutement       Paris (75)
# 463                                    Data Recrutement       Paris (75)
# 467                                         Sept Lieues       Paris (75)
# 529                              Forensic Risk Alliance       Paris (75)
# 530                                              Konekt       Paris (75)
# 549                                         AssessFirst       Paris (75)
# 550                                    Data Recrutement       Paris (75)
# 564                                               AKOYA       Paris (75)
# 596     LR Associates Cabinet de conseil en Recrutement       Paris (75)
# 600                          FORTIA Financial Solutions    Paris 8e (75)
# 695                                    Data Recrutement       Paris (75)
# 723                                    Data Recrutement       Paris (75)
# 800                                    Data Recrutement       Paris (75)
# 850                                        Publifactory    Paris 8e (75)
# 852                                        Easy Partner       Paris (75)
# 891                                          Harnham US       Paris (75)
# 944                                             Quinten       Paris (75)
# 1095                                       EASY PARTNER       Paris (75)
# 1097                                             Inserm   Villejuif (94)
# 1117                                              Seyos    Paris 9e (75)
# 1192                                   Data Recrutement       Paris (75)
# 1210                                      Universcience       Paris (75)
# 1319                                       EASY PARTNER       Paris (75)
# 1327                                             KONEKT       Paris (75)
# 1432                                   Data Recrutement       Paris (75)
# 1508            RTE - Réseau de Transport d'Electricité    Nanterre (92)
# 1510                                       Puce & Plume   Paris 12e (75)
# 1701                           ESILV - Paris la Défense  La Défense (92)
# 1743                                            Onogone       Paris (75)
# 1774                                             Konekt       Paris (75)
# 1797                                             Inserm       Paris (75)
#
#                           salary
# 4       75000 € - 85000 € par an
# 20      19000 € - 22000 € par an
# 50      50000 € - 60000 € par an
# 54                42000 € par an
# 83      44000 € - 50000 € par an
# 84                70000 € par an
# 122               40000 € par an
# 128     55000 € - 65000 € par an
# 138     26000 € - 36000 € par an
# 159               25000 € par an
# 168               85000 € par an
# 173               42000 € par an
# 211     28000 € - 35000 € par an
# 226   120000 € - 140000 € par an
# 263     45000 € - 55000 € par an
# 312     50000 € - 65000 € par an
# 360     60000 € - 70000 € par an
# 364               60000 € par an
# 389     55000 € - 85000 € par an
# 421     44000 € - 57000 € par an
# 463     40000 € - 50000 € par an
# 467     45000 € - 65000 € par an
# 529               29000 € par an
# 530     70000 € - 80000 € par an
# 549     37000 € - 50000 € par an
# 550     65000 € - 75000 € par an
# 564               45000 € par an
# 596     35000 € - 40000 € par an
# 600     35000 € - 40000 € par an
# 695     40000 € - 45000 € par an
# 723     60000 € - 88000 € par an
# 800     58000 € - 74000 € par an
# 850               15000 € par an
# 852               70000 € par an
# 891     42000 € - 48000 € par an
# 944     40000 € - 50000 € par an
# 1095   80000 € - 100000 € par an
# 1097    41000 € - 51000 € par an
# 1117    60000 € - 70000 € par an
# 1192    58000 € - 70000 € par an
# 1210    31000 € - 32000 € par an
# 1319    77000 € - 83000 € par an
# 1327              65000 € par an
# 1432    55000 € - 80000 € par an
# 1508              47000 € par an
# 1510    40000 € - 45000 € par an
# 1701    37000 € - 45000 € par an
# 1743    40000 € - 50000 € par an
# 1774    60000 € - 70000 € par an
# 1797    30000 € - 40000 € par an

# %%
# df2['salary'][df2['salary'].astype(str).str.contains('an')]
# df2.head(50)

# %%
# mask = df2['salary'].str.contains(r'mois', na=True)
# df2.loc[mask, 'salary'] = np.nan
#df2.head(50)

# %%
# def extract_average(s):
#     money = list(map(float, re.findall(r'€([\d\.]+)', s)))
#     return sum(money)/len(money)
# extract_average("50 000 € - 60 000 € par an")

# %%
#import string

def extract_number(salary):
    ##salary = str(salary).translate({ord(c): None for c in string.whitespace})
    #salary = str(salary).replace(",","")
    salary = str(salary).replace(",","").replace("€","").replace("-","")
    ##salary =str(salary).replace("par","").replace("an","")
    ##list=[]
    ##list=salary.split(" ")
    ##salary="".join(list)
    ##salary=int(salary)
    salary = [int(s) for s in salary.split() if s.isdigit()]
    if len(salary)>1:
        salary = (sum(salary)/2)
    else:
        salary = (sum(salary))
    return salary

#extract_number("1100 € - 1700 € par mois")
extract_number("50000 € - 60000 € par an")
# Out:
# 55000.0

# %%
# mask1 = df1['salary'].str.contains(r'mois', na=True)
# df1.loc[mask1, 'salary'] = df1['salary'].map(extract_number)
# df1.loc[mask1, 'salary'] = df1['salary']*12
# df1.head(50)
df2['salary'] = df2['salary'].map(extract_number)
df2.head(50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                               job_title  \
# 4                         Senior Data Scientist FinTech
# 20          Data Entry Clerk & Administrative assistant
# 50                                   Data scientist H/F
# 54                             DATA SCIENTIST-ENGINEERS
# 83    Data analyste informatique - Plateforme pour l...
# 84                             Data Engineer - Foodtech
# 122                           Data Scientist Junior F/H
# 128   Data Scientist - Plateforme pour les étudiants...
# 138                CHARGE DE CLIENTÈLE A DISTANCE (H/F)
# 159                                   Junior Data Entry
# 168      Senior Data Scientist – Start Up Fintech - H/F
# 173                 [CDI] Data Scientist-Engineer (F&H)
# 211   Gestionnaire middle office crédits particulier...
# 226   Directeur Data Science pour porter l'offre dat...
# 263                                       Data Engineer
# 312       Data Scientist Senior (équipe big data et IA)
# 360                         Lead Technique Data Science
# 364    Big Data Engineer H/F (IoT, Scala, Spark, Kafka)
# 389                        Ingénieur Machine Learning |
# 421   Consultant data science on site pour un jeune ...
# 463                                          Data Miner
# 467                                Data Scientist - NLP
# 529                                           Associate
# 530                                 Lead Data Scientist
# 549                    Développeur(euse) Big Data (H/F)
# 550   Data scientist Phd pour révolutionner le monde...
# 564                       Consultant(e) (jeune diplômé)
# 596   Ingénieur Consultant Recherche et Innovation -...
# 600                   TECHNICIEN SUPPORT APPLICATIF H/F
# 695                     Data Engineer pour une scale up
# 723   Manager Data pour un cabinet de conseil disrup...
# 800   Data scientist/engineer pour un acteur majeur ...
# 850   FullStack Developer for Open Science [VueJs/Ex...
# 852                            Data Engineer - Foodtech
# 891                      Data Scientist - Jeune Docteur
# 944                           Biostaticien /programmeur
# 1095                         VP Sales – Start-up AdTech
# 1097                              Data Manager SNDS H/F
# 1117                   Experimented Data Engineer - H/F
# 1192  Data engineer Python pour une marketplace à fo...
# 1210                     Chargé∙e de campagne marketing
# 1319                    Senior Data Scientist - FinTech
# 1327                           Développeur Frontend H/F
# 1432                                    Data Architecte
# 1508                                Data Engineer - H/F
# 1510         Responsable ou Chargé de Marketing Digital
# 1701       Chargé d’enseignements en Mécatronique (CDI)
# 1743                        Développeur Front-end [CDI]
# 1774   Data Engineer sénior – plateforme de recrutement
# 1797                 Chargé de pharmacovigilance senior
#
#                                                 company         location  \
# 4                                          Easy Partner             None
# 20    European Society for Blood and Marrow transpla...       Paris (75)
# 50                                               Fed IT             None
# 54                                               Axance   Paris 18e (75)
# 83                                         Easy Partner             None
# 84                                         Easy Partner             None
# 122                                      ESSILOR FRANCE     Créteil (94)
# 128                                        Easy Partner             None
# 138                                  Bourse des crédits    Paris 2e (75)
# 159   European Society for bllod and marrow transpla...       Paris (75)
# 168                                        EASY PARTNER             None
# 173                                   Axance Technology   Paris 18e (75)
# 211                                  Bourse des crédits    Paris 2e (75)
# 226                                    Data Recrutement       Paris (75)
# 263                                              Neoxia       Paris (75)
# 312                                               DRYFT       Paris (75)
# 360                                          Harnham US       Paris (75)
# 364                                        Square Sense       Paris (75)
# 389                                          OCTOPUS IT       Paris (75)
# 421                                    Data Recrutement       Paris (75)
# 463                                    Data Recrutement       Paris (75)
# 467                                         Sept Lieues       Paris (75)
# 529                              Forensic Risk Alliance       Paris (75)
# 530                                              Konekt       Paris (75)
# 549                                         AssessFirst       Paris (75)
# 550                                    Data Recrutement       Paris (75)
# 564                                               AKOYA       Paris (75)
# 596     LR Associates Cabinet de conseil en Recrutement       Paris (75)
# 600                          FORTIA Financial Solutions    Paris 8e (75)
# 695                                    Data Recrutement       Paris (75)
# 723                                    Data Recrutement       Paris (75)
# 800                                    Data Recrutement       Paris (75)
# 850                                        Publifactory    Paris 8e (75)
# 852                                        Easy Partner       Paris (75)
# 891                                          Harnham US       Paris (75)
# 944                                             Quinten       Paris (75)
# 1095                                       EASY PARTNER       Paris (75)
# 1097                                             Inserm   Villejuif (94)
# 1117                                              Seyos    Paris 9e (75)
# 1192                                   Data Recrutement       Paris (75)
# 1210                                      Universcience       Paris (75)
# 1319                                       EASY PARTNER       Paris (75)
# 1327                                             KONEKT       Paris (75)
# 1432                                   Data Recrutement       Paris (75)
# 1508            RTE - Réseau de Transport d'Electricité    Nanterre (92)
# 1510                                       Puce & Plume   Paris 12e (75)
# 1701                           ESILV - Paris la Défense  La Défense (92)
# 1743                                            Onogone       Paris (75)
# 1774                                             Konekt       Paris (75)
# 1797                                             Inserm       Paris (75)
#
#         salary
# 4      80000.0
# 20     20500.0
# 50     55000.0
# 54     42000.0
# 83     47000.0
# 84     70000.0
# 122    40000.0
# 128    60000.0
# 138    31000.0
# 159    25000.0
# 168    85000.0
# 173    42000.0
# 211    31500.0
# 226   130000.0
# 263    50000.0
# 312    57500.0
# 360    65000.0
# 364    60000.0
# 389    70000.0
# 421    50500.0
# 463    45000.0
# 467    55000.0
# 529    29000.0
# 530    75000.0
# 549    43500.0
# 550    70000.0
# 564    45000.0
# 596    37500.0
# 600    37500.0
# 695    42500.0
# 723    74000.0
# 800    66000.0
# 850    15000.0
# 852    70000.0
# 891    45000.0
# 944    45000.0
# 1095   90000.0
# 1097   46000.0
# 1117   65000.0
# 1192   64000.0
# 1210   31500.0
# 1319   80000.0
# 1327   65000.0
# 1432   67500.0
# 1508   47000.0
# 1510   42500.0
# 1701   41000.0
# 1743   45000.0
# 1774   65000.0
# 1797   35000.0

# %%
# frames = [df1, df2]

# df3 = pd.concat(frames)

# df2= df1.replace({'\n':''}, regex=True)
# mask2 = df2['salary'].str.contains(r'semaine', na=True)
# mask3 = df1['salary'].str.contains(r'jour', na=True)
# df2.loc[mask2, 'salary'] = df1['salary'].map(extract_number)
# df3 = df1.append(df2)
# df3.head(50)

# %%
# mask3 = df1['salary'].str.contains(r'jour', na=True)
# df1.loc[mask3, 'salary'] = df2['salary'].map(extract_number)

# df2.head(50)

# %%
# mask4 = df1['salary'].str.contains(r'heure', na=True)
# df1.loc[mask4, 'salary'] = df1['salary'].map(extract_number)

# df1.head(50)

# %%
# df2['salary']=df2['salary'].astype('float')

# df2.loc[mask1,'salary'] = df2['salary']*12
# df2.loc[mask2,'salary'] = df2['salary']*52
# df2.loc[mask3,'salary'] = df2['salary']*365
# df2.loc[mask4,'salary'] = df2['salary']*8760
# df2.head(50)

# %%
# df2['salary'] = df2['salary'].map(extract_number)
# #df2['salary'] = df2['salary']*1000
# #df2["salary"] = df2["salary"].astype(int)
# df2.head(50)

# %%
## YOUR CODE HERE
df_master = df2.reset_index(drop=True)
df_master.to_csv("master_df.csv")

# %%
from kafka import KafkaProducer
filepath='master_df.csv'
producer=KafkaProducer(bootstrap_servers='localhost:9092')
producer = KafkaProducer()
with open(filepath) as fp:
    line=fp.readline()
    while line:
        JobsPy=producer.send('PredictingSalaryJobsPost',line.encode())
        line=fp.readline()
        metadata = JobsPy.get()
print(metadata.topic)
print(metadata.partition)
producer = KafkaProducer(bootstrap_servers = 'localhost:9092', retries = 5)
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# <ipython-input-24-90fd9a5b6943> in <module>
#       1 from kafka import KafkaProducer
#       2 filepath='master_df.csv'
# ----> 3 producer=KafkaProducer(bootstrap_servers='localhost:9092')
#       4 producer = KafkaProducer()
#       5 with open(filepath) as fp:
#
# ~/.local/lib/python3.7/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     380                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 381                              **self.config)
#     382
#     383         # Get auto-discovered version from client if necessary
#
# ~/.local/lib/python3.7/site-packages/kafka/client_async.py in __init__(self, **configs)
#     238         if self.config['api_version'] is None:
#     239             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 240             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     241
#     242     def _can_bootstrap(self):
#
# ~/.local/lib/python3.7/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     897             if try_node is None:
#     898                 self._lock.release()
# --> 899                 raise Errors.NoBrokersAvailable()
#     900             self._maybe_connect(try_node)
#     901             conn = self._conns[try_node]
#
# NoBrokersAvailable: NoBrokersAvailable

# %%
from kafka import KafkaConsumer
import sys
bootstrap_servers = ['localhost:9092']
topicName = 'PredictingSalaryJobsPost'
#consumer = KafkaConsumer('test')
#for msg in consumer:
    #print(msg)
consumer = KafkaConsumer (topicName, group_id = 'PredictingSalaryJobsgroup',bootstrap_servers = bootstrap_servers,
                          auto_offset_reset = 'earliest')
try:
    for message in consumer:
        print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,message.offset, message.key,message.value))

except KeyboardInterrupt:
    sys.exit()

# %%
df_master = pd.read_csv("master_df.csv")

# %%
df_master.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df_master.head()

# %%
df_master.job_title.unique()

# %%
df_master.company.unique()

# %%
categories = pd.DataFrame(columns=['Gouvernement','Education','Sante','Royal','Recrutement','Finance','Energie'])

# %%
job_words = pd.DataFrame(columns=['Directeur','Analyst','Scientist','Engineer','Business','Consultant','Senior',
                                  'Junior','Manager','Officer','Developer','Head of','Programmeur','Executive',
                                  'Java','Python','Lead','Intelligence','Machine Learning','Javascript','Developer',
                                  'Graduate','Recherche'])

# %%
df_master = pd.concat([df_master,categories,job_words],axis=1)

# %%
for key,value in categories.items():
    df_master[key] = df_master.company.map(lambda x: 1 if len(set(x.split()).intersection(set(value)))>0 else 0)

# %%
for job in job_words:
    df_master[job] = df_master['job_title'].map(lambda x: 1 if job in x else 0)

# %%
df_master['salary_band'] = df_master.salary.map(lambda x: "low" if x <= df_master.salary.quantile(0.5) else "high")

# %%
df_master.head(10)

# %%
df_master.drop_duplicates(inplace=True)

# %%
df_master.shape

# %%
final_df = df_master.copy()
final_df['salary_band'] = final_df.salary.map(lambda x: 0 if x <= final_df.salary.quantile(0.5) else 1)

# %%
## YOUR CODE HERE
print("Baseline Accuracy:",final_df.salary_band.value_counts().max()/sum(final_df.salary_band.value_counts()))

# %%
final_df.shape

# %%
final_df.groupby(by="location").salary.mean().plot(figsize=(20, 6),kind="bar");

# %%
X = final_df['location']
y = final_df['salary_band']

# %%
X = pd.get_dummies(X) #dropping York in the predictors df, as this has the lowest mean salary as displayed above

# %%
#X.drop("York",inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict, cross_val_score, train_test_split
from scipy import stats
import statsmodels.formula.api as sm
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

lr = LogisticRegression()

lr.fit(X,y)

print(lr.score(X,y))

lr.coef_
lr.intercept_

# %%
final_df.head()
predictor_df = final_df.copy()

# %%
predictor_df.columns
predictor_df.drop(['company','job_title','location'],axis=1,inplace=True)

# %%
predictor_df.drop('salary',axis=1,inplace=True)

# %%
predictor_df = pd.get_dummies(predictor_df)

# %%
y = predictor_df.pop('salary_band')

# %%
X_train, X_test, y_train, y_test = train_test_split(predictor_df,y,test_size=0.3,random_state=2018)

# %%
cross_val_score(lr,X_train,y_train,cv=5).mean()

# %%
lr.get_params

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
params = {'C':np.logspace(-5,5,50),
          'penalty':['l1','l2']}
lrgs = GridSearchCV(lr,params,verbose=1,cv=5)
lrgs.fit(X_train,y_train)

# %%
lrgs.best_params_

# %%
lrgs.best_score_

# %%
best_lr = lrgs.best_estimator_

# %%
coefficient_df = pd.DataFrame()
coefficient_df['Features'] = X_train.columns
coefficient_df['LR_Coefficients'] = best_lr.coef_[0]
coefficient_df['absolutes'] = abs(best_lr.coef_[0])

# %%
coefficient_df.sort_values(by='absolutes',ascending=False).head(10)

# %%
best_lr.score(X_test,y_test)

# %%
predictions = best_lr.predict(X_test)
predictions_df = pd.DataFrame()
predictions_df['y_true'] = y_test
predictions_df['y_hat'] = predictions
predictions_df['prob_1'] = best_lr.predict_proba(X_test)[:,1]
predictions_df['70_percent_threshold'] = predictions_df['prob_1'].map(lambda x: 1 if x>0.7 else 0)
predictions_df.head(10)

# %%
from sklearn.metrics import f1_score, roc_curve, precision_recall_curve, auc, average_precision_score

f1_score(y_test, predictions_df['70_percent_threshold'])

# %%
from sklearn import metrics
fpr, tpr, thresh = roc_curve(y_test,predictions_df['prob_1'])
thresholds_df = pd.DataFrame()
thresholds_df['FPR'] = fpr
thresholds_df['TPR'] = tpr
thresholds_df['Thresholds'] = thresh
thresholds_df.iloc[:,:].head(5)

# %%
prec, recall, thresh = precision_recall_curve(y_test,predictions_df['prob_1'])
prc_df = pd.DataFrame()
prc_df['Precision'] = prec[:-1]
prc_df['Recall'] = recall[:-1]
prc_df['Threshold'] = thresh

# %%
average_precision = average_precision_score(y_test, predictions_df['prob_1'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.step(recall, prec, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, prec, step='post', alpha=0.2,
                 color='b')
plt.rcParams["figure.figsize"] = (60,15)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision));

# %%
import seaborn as sns
fig,ax= plt.subplots(figsize=(15,15))
sns.barplot(y=coefficient_df.Features,x=coefficient_df.LR_Coefficients, orient='h', palette='coolwarm',ax=ax);

# %%
plt.plot(fpr,tpr)
plt.plot([0,1],[0,1],'--');

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=5)
cross_val_score(rfc,X_train,y_train,cv=5).mean()

# %%
rfc.get_params()

# %%
X_train.shape

# %%
params = {'max_depth':range(1,21),
          'max_features':["auto","log2",0.5],
         'criterion':['gini','entropy'],
         'bootstrap':[True,False],
         }
rfgs = GridSearchCV(rfc,params,verbose=1,cv=5)
rfgs.fit(X_train,y_train)

# %%
rfgs.best_params_

# %%
rfgs.best_score_

# %%
best_rf = rfgs.best_estimator_

# %%
rf_coefficient_df = pd.DataFrame()
rf_coefficient_df['Features'] = X_train.columns
rf_coefficient_df['Feature_Importances'] = best_rf.feature_importances_

# %%
rf_coefficient_df.sort_values(by='Feature_Importances',ascending=False).head(10)

# %%
best_rf.score(X_test,y_test)

# %%
fig,ax= plt.subplots(figsize=(15,15))
sns.barplot(y=rf_coefficient_df.Features,x=rf_coefficient_df.Feature_Importances, orient='h',ax=ax);

# %%
predictions = best_rf.predict(X_test)
predictions_df = pd.DataFrame()
predictions_df['y_true'] = y_test
predictions_df['y_hat'] = predictions
predictions_df['prob_1'] = best_rf.predict_proba(X_test)[:,1]
predictions_df['70_percent_threshold'] = predictions_df['prob_1'].map(lambda x: 1 if x>0.7 else 0)
predictions_df.head(10)

# %%
f1_score(y_test, predictions_df['70_percent_threshold'])

# %%
fpr, tpr, thresh = roc_curve(y_test,predictions_df['prob_1'])
thresholds_df = pd.DataFrame()
thresholds_df['FPR'] = fpr
thresholds_df['TPR'] = tpr
thresholds_df['Thresholds'] = thresh

# %%
import matplotlib as mpl
plt.plot(fpr,tpr)
plt.rcParams["figure.figsize"] = (100,15)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 10
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.plot([0,1],[0,1],'--');
